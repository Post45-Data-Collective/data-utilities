# %% [markdown]
# # Wikidata Download - Reconcile with no Biblographic Data
#
# This script adds the Wikidata Q number from the Wikdiata API to a TSV file.
#
# The script makes some assumstions based on looking for authors/poets/writes/ect
#
# This script modifies the TSV file itself in batches, should the script timeout or other error you can rerun it and it will pickup where it left off, always run it on a backup of your orginal data files.
#
# It creates a new column in the file `wikidata_qid` which holds the MARC XML

# %%
import pandas as pd
import requests
import time
import string
import unicodedata

# %% [markdown]
# ## Config
# Set these variables below based on your setup
#
# `path_to_tsv` - the path to the TSV file you want to run it on
#
# `id_column_name` - the name of the column header that contains persons name
#
# `user_agent` - this is the value put into the headers on each request, it is good practice to identifiy your client/project when working with open free APIs
#
# `pause_between_req` - number of seconds to wait between each API call

# %%
path_to_tsv = "/Users/m/Downloads/data-tmp/major_literary_prizes-winners_judges.tsv"
id_column_name = "full_name"
id_column_important_data = 'prize_year'
user_agent = 'USER thisismattmiller - Test Script'
pause_between_req = 0

# %%
def add_qid(d):



    # if there is already a value skip it
    if 'author_wikidata' in d:
        if type(d['author_wikidata']) == str:        
            # print('Skip',d[id_column_name])
            return d

    # if pd.isnull(d['match_score']) == False:
    #     if d['match_score'] != 'id title match':
    #       if int(float(d['match_score'])) > 3:
    #         print('skipp')
    #         return d
    #       else:
    #         print(d['author_wikidata'])
    #         d['author_wikidata']  = None
    #         d['author_wikidata_label']  = None
    #         d['author_viaf']  = None
    #         d['author_lccn']  = None
    #         d['match_score']  = None
    #         d['match_log']  = None

            
    #         print(pd.isnull(d['author_wikidata']))

    

    # if d[id_column_name] != 'Claudia Roth Pierpont':
    #     return d

    # # if you want to add any logic to only download some records add it here
    # if type(d['author_lccn']) != str:
    #     print('Skip no LCCN')
    #     return d

    # if d['role'] != 'winner':
    #     return d

 
    if d[id_column_name] == 'No Winner':
        return d

    # # first fire a query off for a name match / this is using the autocomplete, not the full search we can use either
    # url = "https://www.wikidata.org/w/api.php"
    # params = {
    #     'action':'wbsearchentities',
    #     'search':d[id_column_name],
    #     'format':'json',
    #     'errorformat':'plaintext',
    #     'language':'en',
    #     'uselang':'en',
    #     'type':'item',
    # }
    # headers = {
    #     'Accept' : 'application/json',
    #     'User-Agent': user_agent
    # }
    # r = requests.get(url, params=params, headers=headers)

    # data = r.json()
    # print("!!!!!",d[id_column_name])
    # print(data)

    # # make a list of the qids to use
    # qids = []
    # for s in data['search']:
    #     qids.append(s['id'])
    
    # use the full search by default
    url = "https://www.wikidata.org/w/api.php"
    params = {
        'action':'query',
        'srsearch':d[id_column_name],
        'format':'json',
        'list':'search',
        'srlimit':'10'
    }
    headers = {
        'Accept' : 'application/json',
        'User-Agent': user_agent
    }
    r = requests.get(url, params=params, headers=headers)

    data = r.json()
    print("!!!!!",d[id_column_name])
    print(data)

    # make a list of the qids to use
    qids = []
    for s in data['query']['search']:
        qids.append(s['title'])

    total_hits = data['query']['searchinfo']['totalhits']


    if len(qids) == 0:
        return d

    # build the SPARQL query we are going to use
    qids_with_quotes = []
    for q in qids:
        qids_with_quotes.append(f'wd:{q}')

    sparql = f"""
        SELECT ?item ?itemLabel ?occupation ?occupationLabel ?birth ?death ?award ?awardLabel ?viaf ?lccn ?education ?educationLabel
        WHERE 
        {{

            VALUES ?item {{ { " ".join(qids_with_quotes)  }}}

            # ?item wdt:P31 wd:Q5.
          
            optional{{
              # ?item wdt:P106 ?occupation.
            }}
            optional{{
              # ?item wdt:P569 ?birth.
            }}
            optional{{
              # ?item wdt:P570 ?death.
            }}          
            optional{{
              # ?item wdt:P166 ?award.
            }}    
            optional{{
              # ?item wdt:P214 ?viaf.
            }}              
            optional{{
              # ?item wdt:P244 ?lccn.
            }}
            optional{{
              # ?item wdt:P69 ?education.
            }}




            SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
        }}
    """
    params = {
        'query' : sparql
    }

    headers = {
        'Accept' : 'application/json',
        'User-Agent': user_agent
    }
    url = "https://query.wikidata.org/sparql"

    print(sparql)
    r = requests.get(url, params=params, headers=headers)

    data = r.json()

    people = {}

    # did we get any results
    if len(data['results']['bindings']) > 0:
      for result in data['results']['bindings']:

        qid = result['item']['value'].split('/')[-1]

        if qid not in people:

          people[qid] = {
            'qid':qid,
            'score':0,
            'score_log':[],
            'occupation':[],
            'birth':None,
            'death':None,
            'viaf':None,
            'lccn':None,
            'label':None,
            'award': [],
            'education':[]
          }
        
        if 'occupationLabel' in result:
          people[qid]['occupation'].append(result['occupationLabel']['value'])
          people[qid]['occupation'] = list(set(people[qid]['occupation']))
        if 'awardLabel' in result:
          people[qid]['award'].append(result['awardLabel']['value'])
          people[qid]['award'] = list(set(people[qid]['award']))

        if 'educationLabel' in result:
          people[qid]['education'].append(result['educationLabel']['value'])
          people[qid]['education'] = list(set(people[qid]['education']))


        if 'itemLabel' in result:
          people[qid]['label'] = result['itemLabel']['value']
        if 'birth' in result:
          try:            
            # if it is set to this value it is "20.th century, which is unhelpful in our use"
            if result['birth']['value'] != '2000-01-01T00:00:00Z':
              people[qid]['birth'] = int(result['birth']['value'].split('-')[0])
          except:
            people[qid]['birth'] = None
        if 'death' in result:
          try:
            if result['death']['value'] != '2000-01-01T00:00:00Z':
              people[qid]['death'] = int(result['death']['value'].split('-')[0])
          except:
            people[qid]['death'] = None
        if 'viaf' in result:
          people[qid]['viaf'] = result['viaf']['value']
        if 'lccn' in result:
          people[qid]['lccn'] = result['lccn']['value']


      

    # they must have a writerly occupation to continue
    for p in people:

      has_writerly_occ = False
      
      for occ in ['writer', 'poet', 'novelist', 'short story writer', 'author', 'literary critic', 'journalist', 'biographer', 'historian', 'comics artist', 'playwright']:
        if occ in people[p]['occupation']:
          has_writerly_occ = True
      
      if has_writerly_occ == False:
        people[p]['score'] = -1
        people[p]['score_log'].append("No writerly occ")
        continue
      else:
        people[p]['score'] = people[p]['score'] +  1
        people[p]['score_log'].append("Has writerly occ")
      

      # points for pretty much the same name from the sheet as in wikidata
      if levenshtein(normalize_string(people[p]['label']),normalize_string(d['full_name'])) < 3:
        people[p]['score'] = people[p]['score'] + 1
        people[p]['score_log'].append("Has very similar name")
      elif levenshtein(normalize_string(people[p]['label']),normalize_string(d['full_name'])) >= 3:
        people[p]['score'] = people[p]['score'] - 1
      elif levenshtein(normalize_string(people[p]['label']),normalize_string(d['full_name'])) >= 5:
        people[p]['score'] = people[p]['score'] - 2
      elif levenshtein(normalize_string(people[p]['label']),normalize_string(d['full_name'])) >= 8:
        people[p]['score'] = people[p]['score'] - 3        

      # points for having a VIAF or LCCN
      if people[p]['lccn'] != None or people[p]['viaf'] != None:
        people[p]['score'] = people[p]['score'] + 1
        people[p]['score_log'].append("Has VIAF OR LCCN")
      
      # points for being not dead when the award was granted
      if people[p]['death'] != None:
        try:
          award_year = int(d['prize_year'])
          if award_year <= people[p]['death']:
            people[p]['score'] = people[p]['score'] + 1     
            people[p]['score_log'].append("not dead when awarded")

        except:
          pass
      
      # if they were not born when the award was granted then very bad
      if people[p]['birth'] != None:
        try:
          
          award_year = int(d['prize_year'])
          if award_year <= people[p]['birth']:
            people[p]['score'] = -1
            people[p]['score_log'].append("not alive when awarded = -1")        
        except:
          pass
      
      if len(people[p]['award']) >0 and type(d['prize_name']) == str:
        awards = " ".join(people[p]['award']).lower().replace('fellowship','').replace('prize','').replace('award','')
        if d['prize_name'].lower().replace('fellowship','').replace('prize','').replace('award','') in awards:
          people[p]['score'] = people[p]['score'] + 1
          people[p]['score_log'].append("matched on award")        


      if len(people[p]['education']) > 0  != None and type(d['elite_institution']) == str:
        edu = " ".join(people[p]['education']).lower().replace('university of ','').replace('university','').replace('college','')
        if d['elite_institution'].lower().replace('university of ','').replace('university','').replace('college','') in edu:
          people[p]['score'] = people[p]['score'] + 1
          people[p]['score_log'].append("matched on edu")        

      if len(people[p]['education']) > 0  != None and type(d['mfa_degree']) == str:
        edu = " ".join(people[p]['education']).lower().replace('university of ','').replace('university','').replace('college','')
        if d['mfa_degree'].lower().replace('university of ','').replace('university','').replace('college','') in edu:
          people[p]['score'] = people[p]['score'] + 1
          people[p]['score_log'].append("matched on edu")  


      

    print(people)
    best_person_score = 0
    best_person = None
    for p in people:
      if people[p]['score'] > best_person_score:
        best_person_score = people[p]['score']
        best_person = people[p]

    if best_person != None:
      if best_person_score > 1:

        d['author_wikidata'] = best_person['qid']
        d['author_wikidata_label'] = best_person['label']

        if best_person['viaf'] != None:
          d['author_viaf'] = best_person['viaf']
        if best_person['lccn'] != None:
          d['author_lccn'] = best_person['lccn']

        d['match_score'] = best_person_score
        d['match_log'] = "|".join(best_person['score_log'])

    time.sleep(pause_between_req)

    return d

def normalize_string(s):
    s = str(s)
    s = s.translate(str.maketrans('', '', string.punctuation))
    s = " ".join(s.split())
    s = s.lower()
    s = s.casefold()
    s = ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn')
    s = s.replace('the','')
    return s

def levenshtein(s1, s2):
    if len(s1) < len(s2):
        return levenshtein(s2, s1)

    # len(s1) >= len(s2)
    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1 # j+1 instead of j since previous_row and current_row are one character longer
            deletions = current_row[j] + 1       # than s2
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row
    
    return previous_row[-1]

# %%
# load the tsv
df = pd.read_csv(path_to_tsv, sep='\t', header=0, low_memory=False)


# we are going to split the dataframe into chunks so we can save our progress as we go but don't want to save the entire file on on every record operation
n = 100  #chunk row size
list_df = [df[i:i+n] for i in range(0,df.shape[0],n)]

# loop through each chunk
for idx, df_chunk in enumerate(list_df):

    print("Working on chunk ", idx, 'of', len(list_df))
    list_df[idx] = list_df[idx].apply(lambda d: add_qid(d),axis=1 )  
    

    reformed_df = pd.concat(list_df)
    reformed_df.to_csv(path_to_tsv, sep='\t')
# Out:
# Working on chunk  0 of 72
# !!!!! Inge Judd
# {'batchcomplete': '', 'query': {'searchinfo': {'totalhits': 0}, 'search': []}}
# !!!!! Inge Judd
# {'batchcomplete': '', 'query': {'searchinfo': {'totalhits': 0}, 'search': []}}
# !!!!! Inge Judd
# {'batchcomplete': '', 'query': {'searchinfo': {'totalhits': 0}, 'search': []}}
# !!!!! Reuben Bercovitch
# {'batchcomplete': '', 'query': {'searchinfo': {'totalhits': 0}, 'search': []}}
# !!!!! Pauline Hanson
# {'batchcomplete': '', 'continue': {'sroffset': 10, 'continue': '-||'}, 'query': {'searchinfo': {'totalhits': 33}, 'search': [{'ns': 0, 'title': 'Q466220', 'pageid': 439721, 'size': None, 'wordcount': 0, 'snippet': 'Australian politician', 'timestamp': '2023-02-09T10:14:37Z'}, {'ns': 0, 'title': 'Q94510204', 'pageid': 93505444, 'size': None, 'wordcount': 0, 'snippet': '', 'timestamp': '2021-04-12T02:28:13Z'}, {'ns': 0, 'title': 'Q110309825', 'pageid': 105373454, 'size': None, 'wordcount': 0, 'snippet': 'New Zealand tennis player', 'timestamp': '2022-12-13T20:00:57Z'}, {'ns': 0, 'title': 'Q26683448', 'pageid': 28621839, 'size': None, 'wordcount': 0, 'snippet': '2016 film', 'timestamp': '2022-09-28T09:05:02Z'}, {'ns': 0, 'title': 'Q104847192', 'pageid': 100260523, 'size': None, 'wordcount': 0, 'snippet': '', 'timestamp': '2021-01-27T11:26:53Z'}, {'ns': 0, 'title': 'Q1585274', 'pageid': 1520982, 'size': None, 'wordcount': 0, 'snippet': 'Australian political party', 'timestamp': '2023-05-26T14:57:00Z'}, {'ns': 0, 'title': 'Q56096174', 'pageid': 56042162, 'size': None, 'wordcount': 0, 'snippet': '', 'timestamp': '2023-02-11T22:55:35Z'}, {'ns': 0, 'title': 'Q56096173', 'pageid': 56042161, 'size': None, 'wordcount': 0, 'snippet': 'article published in 2004', 'timestamp': '2023-04-13T23:12:13Z'}, {'ns': 0, 'title': 'Q56113531', 'pageid': 56058754, 'size': None, 'wordcount': 0, 'snippet': 'article by Jennifer Rutherford published June 2001 in Australian Journal of Politics and History', 'timestamp': '2022-12-24T14:45:37Z'}, {'ns': 0, 'title': 'Q63737749', 'pageid': 63452220, 'size': None, 'wordcount': 0, 'snippet': '2019 interview of Emma Eros published in The Daily Mail', 'timestamp': '2019-10-28T20:46:14Z'}]}}
#
#         SELECT ?item ?itemLabel ?occupation ?occupationLabel ?birth ?death ?award ?awardLabel ?viaf ?lccn ?education ?educationLabel
#         WHERE
#         {
#
#             VALUES ?item { wd:Q466220 wd:Q94510204 wd:Q110309825 wd:Q26683448 wd:Q104847192 wd:Q1585274 wd:Q56096174 wd:Q56096173 wd:Q56113531 wd:Q63737749}
#
#             ?item wdt:P31 wd:Q5.
#
#             optional{
#               ?item wdt:P106 ?occupation.
#             }
#             optional{
#               ?item wdt:P569 ?birth.
#             }
#             optional{
#               ?item wdt:P570 ?death.
#             }
#             optional{
#               ?item wdt:P166 ?award.
#             }
#             optional{
#               ?item wdt:P214 ?viaf.
#             }
#             optional{
#               ?item wdt:P244 ?lccn.
#             }
#             optional{
#               ?item wdt:P69 ?education.
#             }
#
#
#
#
#             SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }
#
# {'Q466220': {'qid': 'Q466220', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['politician'], 'birth': 1954, 'death': None, 'viaf': '92816054', 'lccn': 'n98054473', 'label': 'Pauline Hanson', 'award': [], 'education': ['Coorparoo State School']}, 'Q94510204': {'qid': 'Q94510204', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': [], 'birth': 1913, 'death': None, 'viaf': '53026748', 'lccn': 'n82032742', 'label': 'Pauline Hanson', 'award': [], 'education': []}, 'Q110309825': {'qid': 'Q110309825', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['tennis player'], 'birth': 1955, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Pauline Elliott', 'award': [], 'education': []}}
# !!!!! Raquelsalas Rivera
# {'batchcomplete': '', 'query': {'searchinfo': {'totalhits': 0}, 'search': []}}
# !!!!! Joel Connaroe
# {'batchcomplete': '', 'query': {'searchinfo': {'totalhits': 0}, 'search': []}}
# !!!!! Jefferson Fletcher
# {'batchcomplete': '', 'continue': {'sroffset': 10, 'continue': '-||'}, 'query': {'searchinfo': {'totalhits':
 'size': None, 'wordcount': 0, 'snippet': 'scientific article published in Physical Review Letters', 'timestamp': '2023-07-19T01:33:53Z'}, {'ns': 0, 'title': 'Q53457222', 'pageid': 54008801, 'size': None, 'wordcount': 0, 'snippet': 'scientific article', 'timestamp': '2023-01-31T19:01:29Z'}, {'ns': 0, 'title': 'Q56547573', 'pageid': 56487173, 'size': None, 'wordcount': 0, 'snippet': 'article', 'timestamp': '2023-07-20T11:21:30Z'}]}}
#
#         SELECT ?item ?itemLabel ?occupation ?occupationLabel ?birth ?death ?award ?awardLabel ?viaf ?lccn ?education ?educationLabel
#         WHERE
#         {
#
#             VALUES ?item { wd:Q884042 wd:Q106568035 wd:Q2113112 wd:Q72697420 wd:Q60045509 wd:Q56899346 wd:Q30277959 wd:Q56668491 wd:Q53457222 wd:Q56547573}
#
#             ?item wdt:P31 wd:Q5.
#
#             optional{
#               ?item wdt:P106 ?occupation.
#             }
#             optional{
#               ?item wdt:P569 ?birth.
#             }
#             optional{
#               ?item wdt:P570 ?death.
#             }
#             optional{
#               ?item wdt:P166 ?award.
#             }
#             optional{
#               ?item wdt:P214 ?viaf.
#             }
#             optional{
#               ?item wdt:P244 ?lccn.
#             }
#             optional{
#               ?item wdt:P69 ?education.
#             }
#
#
#
#
#             SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }
#
# {'Q884042': {'qid': 'Q884042', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['politician'], 'birth': 1862, 'death': 1948, 'viaf': '76467788', 'lccn': 'n50077517', 'label': 'Wilbur Lucius Cross', 'award': ['Sterling Professor'], 'education': ['Natchaug School', 'Yale University']}}
# !!!!! Michael Harper
# {'batchcomplete': '', 'continue': {'sroffset': 10, 'continue': '-||'}, 'query': {'searchinfo': {'totalhits': 1037}, 'search': [{'ns': 0, 'title': 'Q6830956', 'pageid': 6682862, 'size': None, 'wordcount': 0, 'snippet': 'Wikimedia disambiguation page', 'timestamp': '2023-06-09T04:35:54Z'}, {'ns': 0, 'title': 'Q60793041', 'pageid': 60648309, 'size': None, 'wordcount': 0, 'snippet': 'American football player', 'timestamp': '2022-10-09T11:42:21Z'}, {'ns': 0, 'title': 'Q6830957', 'pageid': 6682863, 'size': None, 'wordcount': 0, 'snippet': 'British priest', 'timestamp': '2023-02-24T02:15:46Z'}, {'ns': 0, 'title': 'Q104177262', 'pageid': 99644216, 'size': None, 'wordcount': 0, 'snippet': 'South African cricketer', 'timestamp': '2022-03-01T11:16:08Z'}, {'ns': 0, 'title': 'Q100982540', 'pageid': 98462525, 'size': None, 'wordcount': 0, 'snippet': 'college basketball player (2001–2002) North Carolina-Asheville', 'timestamp': '2022-03-04T00:10:51Z'}, {'ns': 0, 'title': 'Q100982541', 'pageid': 98462526, 'size': None, 'wordcount': 0, 'snippet': 'college basketball player (2013–2014) Hawaii', 'timestamp': '2022-03-04T00:10:51Z'}, {'ns': 0, 'title': 'Q100982539', 'pageid': 98462524, 'size': None, 'wordcount': 0, 'snippet': 'college basketball player (2009–2012) Coppin State', 'timestamp': '2022-03-04T00:10:50Z'}, {'ns': 0, 'title': 'Q100800186', 'pageid': 98353825, 'size': None, 'wordcount': 0, 'snippet': 'college basketball player (2004–2005) Florida A&amp;M', 'timestamp': '2022-03-03T21:57:55Z'}, {'ns': 0, 'title': 'Q5006711', 'pageid': 4783940, 'size': None, 'wordcount': 0, 'snippet': 'American businessman (1927-2016)', 'timestamp': '2021-12-31T08:43:46Z'}, {'ns': 0, 'title': 'Q57625479', 'pageid': 57539210, 'size': None, 'wordcount': 0, 'snippet': 'researcher', 'timestamp': '2023-03-07T22:54:16Z'}]}}
#
#         SELECT ?item ?itemLabel ?occupation ?occupationLabel ?birth ?death ?award ?awardLabel ?viaf ?lccn ?education ?educationLabel
#         WHERE
#         {
#
#             VALUES ?item { wd:Q6830956 wd:Q60793041 wd:Q6830957 wd:Q104177262 wd:Q100982540 wd:Q100982541 wd:Q100982539 wd:Q100800186 wd:Q5006711 wd:Q57625479}
#
#             ?item wdt:P31 wd:Q5.
#
#             optional{
#               ?item wdt:P106 ?occupation.
#             }
#             optional{
#               ?item wdt:P569 ?birth.
#             }
#             optional{
#               ?item wdt:P570 ?death.
#             }
#             optional{
#               ?item wdt:P166 ?award.
#             }
#             optional{
#               ?item wdt:P214 ?viaf.
#             }
#             optional{
#               ?item wdt:P244 ?lccn.
#             }
#             optional{
#               ?item wdt:P69 ?education.
#             }
#
#
#
#
#             SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }
#
# {'Q5006711': {'qid': 'Q5006711', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['businessperson'], 'birth': 1927, 'death': 2016, 'viaf': None, 'lccn': None, 'label': 'C. Michael Harper', 'award': [], 'education': ['Booth School of Business', 'University of Chicago']}, 'Q6830957': {'qid': 'Q6830957', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['priest', 'Anglican priest'], 'birth': 1931, 'death': 2010, 'viaf': '20567983', 'lccn': 'n80034352', 'label': 'Michael Harper', 'award': [], 'education': []}, 'Q57625479': {'qid': 'Q57625479', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['researcher'], 'birth': None, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Zen Michael Harper', 'award': [], 'education': ['University of Leeds']}, 'Q60793041': {'qid': 'Q60793041', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['American football player'], 'birth': 1961, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Michael Harper', 'award': [], 'education': ['University of Southern California']}, 'Q100800186': {'qid': 'Q100800186', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['basketball player'], 'birth': None, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Michael Harper', 'award': [], 'education': ['Florida A&M University']}, 'Q100982539': {'qid': 'Q100982539', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['basketball player'], 'birth': None, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Michael Harper', 'award': [], 'education': ['Coppin State University']}, 'Q100982540': {'qid': 'Q100982540', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['basketball player'], 'birth': None, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Michael Harper', 'award': [], 'education': ['University of North Carolina at Asheville']}, 'Q100982541': {'qid': 'Q100982541', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['basketball player'], 'birth': None, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Michael Harper', 'award': [], 'education': ['University of Hawaiʻi at Mānoa']}, 'Q104177262': {'qid': 'Q104177262', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['cricketer'], 'birth': 1945, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Michael Harper', 'award': [], 'education': []}}
# !!!!! Mark Athitakis
# {'batchcomplete': '', 'query': {'searchinfo': {'totalhits': 1}, 'search': [{'ns': 0, 'title': 'Q111455907', 'pageid': 106417205, 'size': None, 'wordcount': 0, 'snippet': '', 'timestamp': '2022-04-01T20:26:20Z'}]}}
#
#         SELECT ?item ?itemLabel ?occupation ?occupationLabel ?birth ?death ?award ?awardLabel ?viaf ?lccn ?education ?educationLabel
#         WHERE
#         {
#
#             VALUES ?item { wd:Q111455907}
#
#             ?item wdt:P31 wd:Q5.
#
#             optional{
#               ?item wdt:P106 ?occupation.
#             }
#             optional{
#               ?item wdt:P569 ?birth.
#             }
#             optional{
#               ?item wdt:P570 ?death.
#             }
#             optional{
#               ?item wdt:P166 ?award.
#             }
#             optional{
#               ?item wdt:P214 ?viaf.
#             }
#             optional{
#               ?item wdt:P244 ?lccn.
#             }
#             optional{
#               ?item wdt:P69 ?education.
#             }
#
#
#
#
#             SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }
#
# {}
# !!!!! Wilbur L. Cross
# {'batchcomplete': '', 'continue': {'sroffset': 10, 'continue': '-||'}, 'query': {'searchinfo': {'totalhits': 106}, 'search': [{'ns': 0, 'title': 'Q884042', 'pageid': 835097, 'size': None, 'wordcount': 0, 'snippet': 'American politician and scholar (1862–1948)', 'timestamp': '2023-04-08T15:13:50Z'}, {'ns': 0, 'title': 'Q106568035', 'pageid': 101852743, 'size': None, 'wordcount': 0, 'snippet': '1925 Yale Shakespeare volume, edited by <span class="searchmatch">Wilbur</span> <span class="searchmatch">L</span>. <span class="searchmatch">Cross</span> and Tucker Brooke', 'timestamp': '2022-09-06T11:07:32Z'}, {'ns': 0, 'title': 'Q2113112', 'pageid': 2039492, 'size': None, 'wordcount': 0, 'snippet': 'highway in Connecticut', 'timestamp': '2021-10-05T09:37:05Z'}, {'ns': 0, 'title': 'Q72697420', 'pageid': 72359365, 'size': None, 'wordcount': 0, 'snippet': 'scientific article published on 01 May 1994', 'timestamp': '2022-10-05T16:21:50Z'}, {'ns': 0, 'title': 'Q60045509', 'pageid': 59924268, 'size': None, 'wordcount': 0, 'snippet': '', 'timestamp': '2022-09-29T21:43:13Z'}, {'ns': 0, 'title': 'Q56899346', 'pageid': 56816287, 'size': None, 'wordcount': 0, 'snippet': 'article', 'timestamp': '2023-07-19T14:37:11Z'}, {'ns': 0, 'title': 'Q30277959', 'pageid': 31890632, 'size': None, 'wordcount': 0, 'snippet': 'scientific article', 'timestamp': '2023-07-20T11:22:29Z'}, {'ns': 0, 'title': 'Q56668491', 'pageid': 56609540, 'size': None, 'wordcount': 0, 'snippet': 'scientific article published in Physical Review Letters', 'timestamp': '2023-07-19T01:33:53Z'}, {'ns': 0, 'title': 'Q53457222', 'pageid': 54008801, 'size': None, 'wordcount': 0, 'snippet': 'scientific article', 'timestamp': '2023-01-31T19:01:29Z'}, {'ns': 0, 'title': 'Q56547573', 'pageid': 56487173, 'size': None, 'wordcount': 0, 'snippet': 'article', 'timestamp': '2023-07-20T11:21:30Z'}]}}
#
#         SELECT ?item ?itemLabel ?occupation ?occupationLabel ?birth ?death ?award ?awardLabel ?viaf ?lccn ?education ?educationLabel
#         WHERE
#         {
#
#             VALUES ?item { wd:Q884042 wd:Q106568035 wd:Q2113112 wd:Q72697420 wd:Q60045509 wd:Q56899346 wd:Q30277959 wd:Q56668491 wd:Q53457222 wd:Q56547573}
#
#             ?item wdt:P31 wd:Q5.
#
#             optional{
#               ?item wdt:P106 ?occupation.
#             }
#             optional{
#               ?item wdt:P569 ?birth.
#             }
#             optional{
#               ?item wdt:P570 ?death.
#             }
#             optional{
#               ?item wdt:P166 ?award.
#             }
#             optional{
#               ?item wdt:P214 ?viaf.
#             }
#             optional{
#               ?item wdt:P244 ?lccn.
#             }
#             optional{
#               ?item wdt:P69 ?education.
#             }
#
#
#
#
#             SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }
#
# {'Q884042': {'qid': 'Q884042', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['politician'], 'birth': 1862, 'death': 1948, 'viaf': '76467788', 'lccn': 'n50077517', 'label': 'Wilbur Lucius Cross', 'award': ['Sterling Professor'], 'education': ['Natchaug School', 'Yale University']}}
# !!!!! Benjamine Alire Saenz
# {'batchcomplete': '', 'query': {'searchinfo': {'totalhits': 0}, 'search': []}}
# !!!!! Madison Smart Bell
# {'batchcomplete': '', 'query': {'searchinfo': {'totalhits': 0}, 'search': []}}
# !!!!! Charles Rowell
# {'batchcomplete': '', 'continue': {'sroffset': 10, 'continue': '-||'}, 'query': {'searchinfo': {'totalhits': 53}, 'search': [{'ns': 0, 'title': 'Q28747968', 'pageid': 30406962, 'size': None, 'wordcount': 0, 'snippet': 'English athlete', 'timestamp': '2022-09-18T13:29:22Z'}, {'ns': 0, 'title': 'Q104530873', 'pageid': 99933205, 'size': None, 'wordcount': 0, 'snippet': 'Kiowa artist', 'timestamp': '2023-03-14T09:59:32Z'}, {'ns': 0, 'title': 'Q28912516', 'pageid': 30573356, 'size': None, 'wordcount': 0, 'snippet': '', 'timestamp': '2022-09-04T18:58:54Z'}, {'ns': 0, 'title': 'Q109796072', 'pageid': 104899799, 'size': None, 'wordcount': 0, 'snippet': '', 'timestamp': '2021-11-30T18:07:35Z'}, {'ns': 0, 'title': 'Q95286586', 'pageid': 94186971, 'size': None, 'wordcount': 0, 'snippet': '', 'timestamp': '2021-02-16T13:13:09Z'}, {'ns': 0, 'title': 'Q46028922', 'pageid': 47176156, 'size': None, 'wordcount': 0, 'snippet': 'scientific article published in July 2001', 'timestamp': '2022-11-13T06:30:03Z'}, {'ns': 0, 'title': 'Q92734364', 'pageid': 91898134, 'size': None, 'wordcount': 0, 'snippet': 'scientific article published on 01 January 1991', 'timestamp': '2022-07-11T20:50:02Z'}, {'ns': 0, 'title': 'Q114820190', 'pageid': 109486715, 'size': None, 'wordcount': 0, 'snippet': 'scientific article published in 2021', 'timestamp': '2023-07-18T00:49:01Z'}, {'ns': 0, 'title': 'Q83432799', 'pageid': 82749607, 'size': None, 'wordcount': 0, 'snippet': 'scientific article published on 01 November 2008', 'timestamp': '2022-08-24T23:46:32Z'}, {'ns': 0, 'title': 'Q60920698', 'pageid': 60774601, 'size': None, 'wordcount': 0, 'snippet': '', 'timestamp': '2023-05-04T23:53:28Z'}]}}
#
#         SELECT ?item ?itemLabel ?occupation ?occupationLabel ?birth ?death ?award ?awardLabel ?viaf ?lccn ?education ?educationLabel
#         WHERE
#         {
#
#             VALUES ?item { wd:Q28747968 wd:Q104530873 wd:Q28912516 wd:Q109796072 wd:Q95286586 wd:Q46028922 wd:Q92734364 wd:Q114820190 wd:Q83432799 wd:Q60920698}
#
#             ?item wdt:P31 wd:Q5.
#
#             optional{
#               ?item wdt:P106 ?occupation.
#             }
#             optional{
#               ?item wdt:P569 ?birth.
#             }
#             optional{
#               ?item wdt:P570 ?death.
#             }
#             optional{
#               ?item wdt:P166 ?award.
#             }
#             optional{
#               ?item wdt:P214 ?viaf.
#             }
#             optional{
#               ?item wdt:P244 ?lccn.
#             }
#             optional{
#               ?item wdt:P69 ?education.
#             }
#
#
#
#
#             SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }
#
# {'Q28747968': {'qid': 'Q28747968', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['athlete'], 'birth': 1852, 'death': 1909, 'viaf': None, 'lccn': None, 'label': 'Charles Rowell', 'award': [], 'education': []}, 'Q28912516': {'qid': 'Q28912516', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['judge', 'lawyer'], 'birth': 1921, 'death': 2017, 'viaf': None, 'lccn': None, 'label': 'John Fieldsend', 'award': ['Knight Commander of the Order of the British Empire'], 'education': ['Rhodes University', 'Michaelhouse']}, 'Q95286586': {'qid': 'Q95286586', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['zoologist'], 'birth': 1933, 'death': None, 'viaf': '5081407', 'lccn': None, 'label': 'Charles H. F. Rowell', 'award': [], 'education': []}, 'Q104530873': {'qid': 'Q104530873', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['painter'], 'birth': 1909, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Charles Emery Rowell', 'award': [], 'education': []}, 'Q109796072': {'qid': 'Q109796072', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': [], 'birth': None, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Charles W. Rowell', 'award': [], 'education': ['United States Military Academy']}}
# !!!!! Nicholas Delbanco
# {'batchcomplete': '', 'query': {'searchinfo': {'totalhits': 1}, 'search': [{'ns': 0, 'title': 'Q15451732', 'pageid': 17095311, 'size': None, 'wordcount': 0, 'snippet': 'American writer', 'timestamp': '2023-03-10T17:15:04Z'}]}}
#
#         SELECT ?item ?itemLabel ?occupation ?occupationLabel ?birth ?death ?award ?awardLabel ?viaf ?lccn ?education ?educationLabel
#         WHERE
#         {
#
#             VALUES ?item { wd:Q15451732}
#
#             ?item wdt:P31 wd:Q5.
#
#             optional{
#               ?item wdt:P106 ?occupation.
#             }
#             optional{
#               ?item wdt:P569 ?birth.
#             }
#             optional{
#               ?item wdt:P570 ?death.
#             }
#             optional{
#               ?item wdt:P166 ?award.
#             }
#             optional{
#               ?item wdt:P214 ?viaf.
#             }
#             optional{
#               ?item wdt:P244 ?lccn.
#             }
#             optional{
#               ?item wdt:P69 ?education.
#             }
#
#
#
#
#             SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }
#
# {'Q15451732': {'qid': 'Q15451732', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['teacher'], 'birth': 1942, 'death': None, 'viaf': '27082662', 'lccn': 'n80040148', 'label': 'Nicholas Delbanco', 'award': ['Guggenheim Fellowship'], 'education': ['Ethical Culture Fieldston School', 'Harvard University', 'Columbia University']}}
# Working on chunk  1 of 72
# !!!!! Wilbur L. Cross
# {'batchcomplete': '', 'continue': {'sroffset': 10, 'continue': '-||'}, 'query': {'searchinfo': {'totalhits': 106}, 'search': [{'ns': 0, 'title': 'Q884042', 'pageid': 835097, 'size': None, 'wordcount': 0, 'snippet': 'American politician and scholar (1862–1948)', 'timestamp': '2023-04-08T15:13:50Z'}, {'ns': 0, 'title': 'Q106568035', 'pageid': 101852743, 'size': None, 'wordcount': 0, 'snippet': '1925 Yale Shakespeare volume, edited by <span class="searchmatch">Wilbur</span> <span class="searchmatch">L</span>. <span class="searchmatch">Cross</span> and Tucker Brooke', 'timestamp': '2022-09-06T11:07:32Z'}, {'ns': 0, 'title': 'Q2113112', 'pageid': 2039492, 'size': None, 'wordcount': 0, 'snippet': 'highway in Connecticut', 'timestamp': '2021-10-05T09:37:05Z'}, {'ns': 0, 'title': 'Q72697420', 'pageid': 72359365, 'size': None, 'wordcount': 0, 'snippet': 'scientific article published on 01 May 1994', 'timestamp': '2022-10-05T16:21:50Z'}, {'ns': 0, 'title': 'Q60045509', 'pageid': 59924268, 'size': None, 'wordcount': 0, 'snippet': '', 'timestamp': '2022-09-29T21:43:13Z'}, {'ns': 0, 'title': 'Q56899346', 'pageid': 56816287, 'size': None, 'wordcount': 0, 'snippet': 'article', 'timestamp': '2023-07-19T14:37:11Z'}, {'ns': 0, 'title': 'Q30277959', 'pageid': 31890632, 'size': None, 'wordcount': 0, 'snippet': 'scientific article', 'timestamp': '2023-07-20T11:22:29Z'}, {'ns': 0, 'title': 'Q56668491', 'pageid': 56609540, 'size': None, 'wordcount': 0, 'snippet': 'scientific article published in Physical Review Letters', 'timestamp': '2023-07-19T01:33:53Z'}, {'ns': 0, 'title': 'Q53457222', 'pageid': 54008801, 'size': None, 'wordcount': 0, 'snippet': 'scientific article', 'timestamp': '2023-01-31T19:01:29Z'}, {'ns': 0, 'title': 'Q56547573', 'pageid': 56487173, 'size': None, 'wordcount': 0, 'snippet': 'article', 'timestamp': '2023-07-20T11:21:30Z'}]}}
#
#         SELECT ?item ?itemLabel ?occupation ?occupationLabel ?birth ?death ?award ?awardLabel ?viaf ?lccn ?education ?educationLabel
#         WHERE
#         {
#
#             VALUES ?item { wd:Q884042 wd:Q106568035 wd:Q2113112 wd:Q72697420 wd:Q60045509 wd:Q56899346 wd:Q30277959 wd:Q56668491 wd:Q53457222 wd:Q56547573}
#
#             ?item wdt:P31 wd:Q5.
#
#             optional{
#               ?item wdt:P106 ?occupation.
#             }
#             optional{
#               ?item wdt:P569 ?birth.
#             }
#             optional{
#               ?item wdt:P570 ?death.
#             }
#             optional{
#               ?item wdt:P166 ?award.
#             }
#             optional{
#               ?item wdt:P214 ?viaf.
#             }
#             optional{
#               ?item wdt:P244 ?lccn.
#             }
#             optional{
#               ?item wdt:P69 ?education.
#             }
#
#
#
#
#             SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }
#
# {'Q884042': {'qid': 'Q884042', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['politician'], 'birth': 1862, 'death': 1948, 'viaf': '76467788', 'lccn': 'n50077517', 'label': 'Wilbur Lucius Cross', 'award': ['Sterling Professor'], 'education': ['Natchaug School', 'Yale University']}}
# !!!!! Javier Ramirez
# {'batchcomplete': '', 'continue': {'sroffset': 10, 'continue': '-||'}, 'query': {'searchinfo': {'totalhits': 1650}, 'search': [{'ns': 0, 'title': 'Q1324518', 'pageid': 1264261, 'size': None, 'wordcount': 0, 'snippet': 'Spanish bicycle racer', 'timestamp': '2023-04-20T13:44:16Z'}, {'ns': 0, 'title': 'Q3163167', 'pageid': 3021445, 'size': None, 'wordcount': 0, 'snippet': 'Mexican singer', 'timestamp': '2022-02-27T18:11:09Z'}, {'ns': 0, 'title': 'Q37830424', 'pageid': 39201808, 'size': None, 'wordcount': 0, 'snippet': 'researcher', 'timestamp': '2023-07-09T22:53:03Z'}, {'ns': 0, 'title': 'Q47264186', 'pageid': 48310818, 'size': None, 'wordcount': 0, 'snippet': 'researcher', 'timestamp': '2023-03-13T00:33:51Z'}, {'ns': 0, 'title': 'Q47520410', 'pageid': 48563597, 'size': None, 'wordcount': 0, 'snippet': 'Spanish politician', 'timestamp': '2022-10-15T01:09:58Z'}, {'ns': 0, 'title': 'Q982971', 'pageid': 932650, 'size': None, 'wordcount': 0, 'snippet': 'Mexican politician', 'timestamp': '2022-04-16T21:10:05Z'}, {'ns': 0, 'title': 'Q23907003', 'pageid': 25903752, 'size': None, 'wordcount': 0, 'snippet': 'Spanish politician', 'timestamp': '2022-04-02T07:32:27Z'}, {'ns': 0, 'title': 'Q22113298', 'pageid': 24144107, 'size': None, 'wordcount': 0, 'snippet': 'Argentine arachnologist', 'timestamp': '2023-03-11T18:45:17Z'}, {'ns': 0, 'title': 'Q85412201', 'pageid': 84700806, 'size': None, 'wordcount': 0, 'snippet': '', 'timestamp': '2021-03-29T11:45:07Z'}, {'ns': 0, 'title': 'Q14127123', 'pageid': 15792788, 'size': None, 'wordcount': 0, 'snippet': 'Spanish politician', 'timestamp': '2022-03-26T06:04:11Z'}]}}
#
#         SELECT ?item ?itemLabel ?occupation ?occupationLabel ?birth ?death ?award ?awardLabel ?viaf ?lccn ?education ?educationLabel
#         WHERE
#         {
#
#             VALUES ?item { wd:Q1324518 wd:Q3163167 wd:Q37830424 wd:Q47264186 wd:Q47520410 wd:Q982971 wd:Q23907003 wd:Q22113298 wd:Q85412201 wd:Q14127123}
#
#             ?item wdt:P31 wd:Q5.
#
#             optional{
#               ?item wdt:P106 ?occupation.
#             }
#             optional{
#               ?item wdt:P569 ?birth.
#             }
#             optional{
#               ?item wdt:P570 ?death.
#             }
#             optional{
#               ?item wdt:P166 ?award.
#             }
#             optional{
#               ?item wdt:P214 ?viaf.
#             }
#             optional{
#               ?item wdt:P244 ?lccn.
#             }
#             optional{
#               ?item wdt:P69 ?education.
#             }
#
#
#
#
#             SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }
#
# ...
#               ?item wdt:P69 ?education.
#             }
#
#
#
#
#             SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }
#
# {'Q5363326': {'qid': 'Q5363326', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['singer'], 'birth': 1846, 'death': 1924, 'viaf': None, 'lccn': None, 'label': 'Elizabeth Parsons', 'award': [], 'education': []}, 'Q18756683': {'qid': 'Q18756683', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['impostor'], 'birth': 1749, 'death': 1807, 'viaf': None, 'lccn': None, 'label': 'Elizabeth Parsons', 'award': [], 'education': []}, 'Q75259561': {'qid': 'Q75259561', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': [], 'birth': None, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Elizabeth Parsons', 'award': [], 'education': []}, 'Q75398067': {'qid': 'Q75398067', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': [], 'birth': None, 'death': 1768, 'viaf': None, 'lccn': None, 'label': 'Elizabeth Parsons', 'award': [], 'education': []}, 'Q75785443': {'qid': 'Q75785443', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': [], 'birth': None, 'death': 1638, 'viaf': None, 'lccn': None, 'label': 'Elizabeth Parsons', 'award': [], 'education': []}, 'Q75856293': {'qid': 'Q75856293', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': [], 'birth': 1846, 'death': 1889, 'viaf': None, 'lccn': None, 'label': 'Elizabeth Parsons', 'award': [], 'education': []}, 'Q75856556': {'qid': 'Q75856556', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': [], 'birth': 1885, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Elizabeth Parsons', 'award': [], 'education': []}, 'Q76370636': {'qid': 'Q76370636', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': [], 'birth': None, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Elizabeth Parsons', 'award': [], 'education': []}, 'Q83521182': {'qid': 'Q83521182', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['painter', 'lithographer'], 'birth': 1831, 'death': 1897, 'viaf': '93008067', 'lccn': None, 'label': 'Elizabeth Parsons', 'award': [], 'education': []}, 'Q112505575': {'qid': 'Q112505575', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['manager', 'university teacher', 'opinion journalist'], 'birth': 1957, 'death': None, 'viaf': '4406062', 'lccn': 'n2008050550', 'label': 'Elizabeth Parsons', 'award': [], 'education': []}}
# !!!!! Hildad Doolittle
# {'batchcomplete': '', 'query': {'searchinfo': {'totalhits': 0}, 'search': []}}
# !!!!! Isabella Borgeson
# {'batchcomplete': '', 'query': {'searchinfo': {'totalhits': 0}, 'search': []}}
# Working on chunk  69 of 72
# !!!!! Jennifer Nansubugamakumbi
# {'batchcomplete': '', 'query': {'searchinfo': {'totalhits': 0}, 'search': []}}
# !!!!! Kennedy Fraser
# {'batchcomplete': '', 'continue': {'sroffset': 10, 'continue': '-||'}, 'query': {'searchinfo': {'totalhits': 143}, 'search': [{'ns': 0, 'title': 'Q6389612', 'pageid': 6202660, 'size': None, 'wordcount': 0, 'snippet': 'American writer', 'timestamp': '2022-10-11T13:47:00Z'}, {'ns': 0, 'title': 'Q6766361', 'pageid': 6612277, 'size': None, 'wordcount': 0, 'snippet': 'British singer (1857-1930)', 'timestamp': '2023-07-10T10:42:27Z'}, {'ns': 0, 'title': 'Q108753266', 'pageid': 103980338, 'size': None, 'wordcount': 0, 'snippet': 'b.25 March 1909 d.4 November 1984', 'timestamp': '2022-01-11T20:04:43Z'}, {'ns': 0, 'title': 'Q24579049', 'pageid': 26544750, 'size': None, 'wordcount': 0, 'snippet': 'Scottish psychologist, educator and amateur mathematician', 'timestamp': '2022-02-13T20:17:20Z'}, {'ns': 0, 'title': 'Q93096921', 'pageid': 92244442, 'size': None, 'wordcount': 0, 'snippet': 'researcher (ORCID 0000-0003-1796-0764)', 'timestamp': '2021-03-11T00:19:03Z'}, {'ns': 0, 'title': 'Q27956343', 'pageid': 29662052, 'size': None, 'wordcount': 0, 'snippet': 'painting by John Duncan', 'timestamp': '2023-05-14T11:23:59Z'}, {'ns': 0, 'title': 'Q37732641', 'pageid': 39105085, 'size': None, 'wordcount': 0, 'snippet': 'Born: 3 May 1857 in Cargill, near Perth, Scotland; Died: 9 November 1890 in Glasgow, Scotland', 'timestamp': '2022-04-19T17:10:51Z'}, {'ns': 0, 'title': 'Q75940787', 'pageid': 75427950, 'size': None, 'wordcount': 0, 'snippet': '(1878-1954)', 'timestamp': '2022-07-29T14:34:32Z'}, {'ns': 0, 'title': 'Q76331888', 'pageid': 75820543, 'size': None, 'wordcount': 0, 'snippet': 'Peerage person ID=694703', 'timestamp': '2022-07-29T14:35:44Z'}, {'ns': 0, 'title': 'Q94041621', 'pageid': 93084711, 'size': None, 'wordcount': 0, 'snippet': '', 'timestamp': '2020-08-24T18:47:34Z'}]}}
#
#         SELECT ?item ?itemLabel ?occupation ?occupationLabel ?birth ?death ?award ?awardLabel ?viaf ?lccn ?education ?educationLabel
#         WHERE
#         {
#
#             VALUES ?item { wd:Q6389612 wd:Q6766361 wd:Q108753266 wd:Q24579049 wd:Q93096921 wd:Q27956343 wd:Q37732641 wd:Q75940787 wd:Q76331888 wd:Q94041621}
#
#             ?item wdt:P31 wd:Q5.
#
#             optional{
#               ?item wdt:P106 ?occupation.
#             }
#             optional{
#               ?item wdt:P569 ?birth.
#             }
#             optional{
#               ?item wdt:P570 ?death.
#             }
#             optional{
#               ?item wdt:P166 ?award.
#             }
#             optional{
#               ?item wdt:P214 ?viaf.
#             }
#             optional{
#               ?item wdt:P244 ?lccn.
#             }
#             optional{
#               ?item wdt:P69 ?education.
#             }
#
#
#
#
#             SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }
#
# {'Q6389612': {'qid': 'Q6389612', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['essayist'], 'birth': 1948, 'death': None, 'viaf': '17400473', 'lccn': 'n81077285', 'label': 'Kennedy Fraser', 'award': ['Guggenheim Fellowship'], 'education': []}, 'Q6766361': {'qid': 'Q6766361', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['musicologist', 'composer', 'singer'], 'birth': 1857, 'death': 1930, 'viaf': '79256496', 'lccn': 'n82047867', 'label': 'Marjory Kennedy-Fraser', 'award': ['Commander of the Order of the British Empire'], 'education': []}, 'Q24579049': {'qid': 'Q24579049', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['psychologist'], 'birth': 1888, 'death': 1962, 'viaf': '91459903', 'lccn': 'n2019186365', 'label': 'David Kennedy Fraser', 'award': ['Fellow of the Royal Society of Edinburgh'], 'education': ['Leipzig University', 'Cornell University', 'University of Edinburgh', "George Watson's College", 'University of Edinburgh Moray House School of Education']}, 'Q37732641': {'qid': 'Q37732641', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['mathematician'], 'birth': 1857, 'death': 1890, 'viaf': None, 'lccn': None, 'label': 'Alexander Fraser', 'award': [], 'education': ['University of Aberdeen']}, 'Q75940787': {'qid': 'Q75940787', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': [], 'birth': 1878, 'death': 1954, 'viaf': None, 'lccn': None, 'label': 'Charles Fraser Kennedy', 'award': [], 'education': []}, 'Q76331888': {'qid': 'Q76331888', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': [], 'birth': None, 'death': 1966, 'viaf': None, 'lccn': None, 'label': 'Anna Fraser Kennedy', 'award': [], 'education': []}, 'Q93096921': {'qid': 'Q93096921', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['researcher'], 'birth': None, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Fraser Kennedy', 'award': [], 'education': []}, 'Q108753266': {'qid': 'Q108753266', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': [], 'birth': 1909, 'death': 1984, 'viaf': None, 'lccn': None, 'label': 'Peter Kennedy Fraser', 'award': [], 'education': []}}
# Working on chunk  70 of 72
# !!!!! Mariairene Fornes
# {'batchcomplete': '', 'query': {'searchinfo': {'totalhits': 0}, 'search': []}}
# !!!!! Marym Colum
# {'batchcomplete': '', 'query': {'searchinfo': {'totalhits': 0}, 'search': []}}
# !!!!! Maxinehong Kingston
# {'batchcomplete': '', 'query': {'searchinfo': {'totalhits': 0}, 'search': []}}
# !!!!! Pat Scott
# {'batchcomplete': '', 'continue': {'sroffset': 10, 'continue': '-||'}, 'query': {'searchinfo': {'totalhits': 225}, 'search': [{'ns': 0, 'title': 'Q111090901', 'pageid': 106086226, 'size': None, 'wordcount': 0, 'snippet': 'Patricia &quot;Pat&quot; Scott (Democrat) represented the 38th Legislative District encompassing Everett and Marysville. Appointed in January, 1984, to serve an unexpired term, she served until her death in January, 2001. Born in Minnesota, she was a resident', 'timestamp': '2023-03-28T09:26:54Z'}, {'ns': 0, 'title': 'Q55446127', 'pageid': 55464165, 'size': None, 'wordcount': 0, 'snippet': 'researcher', 'timestamp': '2023-07-10T03:10:08Z'}, {'ns': 0, 'title': 'Q115922345', 'pageid': 110542366, 'size': None, 'wordcount': 0, 'snippet': 'chief librarian at Upper Norwood Library', 'timestamp': '2023-01-02T12:52:34Z'}, {'ns': 0, 'title': 'Q49060143', 'pageid': 50074267, 'size': None, 'wordcount': 0, 'snippet': '', 'timestamp': '2022-08-18T01:28:15Z'}, {'ns': 0, 'title': 'Q49731193', 'pageid': 50732800, 'size': None, 'wordcount': 0, 'snippet': 'spring in Cochise County, Arizona, United States of America', 'timestamp': '2022-08-07T13:59:03Z'}, {'ns': 0, 'title': 'Q7145831', 'pageid': 7044028, 'size': None, 'wordcount': 0, 'snippet': 'All-American Girls Professional Baseball League player (1929-2016)', 'timestamp': '2022-10-09T05:50:03Z'}, {'ns': 0, 'title': 'Q108694682', 'pageid': 103921975, 'size': None, 'wordcount': 0, 'snippet': 'American jazz singer', 'timestamp': '2023-05-17T18:53:17Z'}, {'ns': 0, 'title': 'Q7756312', 'pageid': 7685517, 'size': None, 'wordcount': 0, 'snippet': 'book by F. Scott Fitzgerald', 'timestamp': '2022-11-27T00:53:00Z'}, {'ns': 0, 'title': 'Q1755210', 'pageid': 1687889, 'size': None, 'wordcount': 0, 'snippet': 'album by Pat Metheny Group', 'timestamp': '2022-12-31T21:38:46Z'}, {'ns': 0, 'title': 'Q64348626', 'pageid': 64048146, 'size': None, 'wordcount': 0, 'snippet': 'fictional character created by F. Scott Fitzgerald', 'timestamp': '2022-07-20T14:58:51Z'}]}}
#
#         SELECT ?item ?itemLabel ?occupation ?occupationLabel ?birth ?death ?award ?awardLabel ?viaf ?lccn ?education ?educationLabel
#         WHERE
#         {
#
#             VALUES ?item { wd:Q111090901 wd:Q55446127 wd:Q115922345 wd:Q49060143 wd:Q49731193 wd:Q7145831 wd:Q108694682 wd:Q7756312 wd:Q1755210 wd:Q64348626}
#
#             ?item wdt:P31 wd:Q5.
#
#             optional{
#               ?item wdt:P106 ?occupation.
#             }
#             optional{
#               ?item wdt:P569 ?birth.
#             }
#             optional{
#               ?item wdt:P570 ?death.
#             }
#             optional{
#               ?item wdt:P166 ?award.
#             }
#             optional{
#               ?item wdt:P214 ?viaf.
#             }
#             optional{
#               ?item wdt:P244 ?lccn.
#             }
#             optional{
#               ?item wdt:P69 ?education.
#             }
#
#
#
#
#             SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }
#
# {'Q7145831': {'qid': 'Q7145831', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['wood carver', 'zoologist', 'baseball player'], 'birth': 1929, 'death': 2016, 'viaf': None, 'lccn': None, 'label': 'Patricia Scott', 'award': [], 'education': ['University of Kentucky']}, 'Q55446127': {'qid': 'Q55446127', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['astrophysicist'], 'birth': 1982, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Pat Scott', 'award': [], 'education': ['Stockholm University']}, 'Q108694682': {'qid': 'Q108694682', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['commissioner', 'director', 'press agent', 'jazz singer', 'television presenter'], 'birth': 1934, 'death': 2020, 'viaf': None, 'lccn': None, 'label': 'Patricia Reed Scott', 'award': [], 'education': ['George Washington University']}, 'Q111090901': {'qid': 'Q111090901', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['politician'], 'birth': None, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Pat Scott', 'award': [], 'education': []}, 'Q115922345': {'qid': 'Q115922345', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['librarian'], 'birth': None, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Pat Scott', 'award': [], 'education': []}}
# Working on chunk  71 of 72
# !!!!! Sumita Chakraborty
# {'batchcomplete': '', 'continue': {'sroffset': 10, 'continue': '-||'}, 'query': {'searchinfo': {'totalhits': 30}, 'search': [{'ns': 0, 'title': 'Q91832319', 'pageid': 91012723, 'size': None, 'wordcount': 0, 'snippet': 'stem cell researcher (ORCID 0000-0002-8917-6875)', 'timestamp': '2022-11-04T02:48:15Z'}, {'ns': 0, 'title': 'Q115048549', 'pageid': 109700367, 'size': None, 'wordcount': 0, 'snippet': 'poet, editor', 'timestamp': '2022-11-04T02:57:31Z'}, {'ns': 0, 'title': 'Q94463292', 'pageid': 93459935, 'size': None, 'wordcount': 0, 'snippet': 'scientific article published on 29 April 2020', 'timestamp': '2022-10-11T08:02:14Z'}, {'ns': 0, 'title': 'Q91376398', 'pageid': 90558850, 'size': None, 'wordcount': 0, 'snippet': 'scientific article published on 01 January 2018', 'timestamp': '2022-09-21T12:25:25Z'}, {'ns': 0, 'title': 'Q37977190', 'pageid': 39346661, 'size': None, 'wordcount': 0, 'snippet': 'scientific article published on February 2012', 'timestamp': '2022-09-24T18:14:29Z'}, {'ns': 0, 'title': 'Q60916013', 'pageid': 60769924, 'size': None, 'wordcount': 0, 'snippet': '', 'timestamp': '2022-06-14T07:53:39Z'}, {'ns': 0, 'title': 'Q37381263', 'pageid': 38756971, 'size': None, 'wordcount': 0, 'snippet': 'scientific article published on 02 September 2016', 'timestamp': '2023-03-13T00:07:44Z'}, {'ns': 0, 'title': 'Q64260975', 'pageid': 63962582, 'size': None, 'wordcount': 0, 'snippet': 'scientific article published on 01 February 2019', 'timestamp': '2023-05-04T20:08:07Z'}, {'ns': 0, 'title': 'Q33577469', 'pageid': 35023556, 'size': None, 'wordcount': 0, 'snippet': 'scientific article', 'timestamp': '2021-12-24T07:52:38Z'}, {'ns': 0, 'title': 'Q44108475', 'pageid': 45308689, 'size': None, 'wordcount': 0, 'snippet': 'scientific article published on 16 August 2002', 'timestamp': '2021-02-18T05:32:37Z'}]}}
#
#         SELECT ?item ?itemLabel ?occupation ?occupationLabel ?birth ?death ?award ?awardLabel ?viaf ?lccn ?education ?educationLabel
#         WHERE
#         {
#
#             VALUES ?item { wd:Q91832319 wd:Q115048549 wd:Q94463292 wd:Q91376398 wd:Q37977190 wd:Q60916013 wd:Q37381263 wd:Q64260975 wd:Q33577469 wd:Q44108475}
#
#             ?item wdt:P31 wd:Q5.
#
#             optional{
#               ?item wdt:P106 ?occupation.
#             }
#             optional{
#               ?item wdt:P569 ?birth.
#             }
#             optional{
#               ?item wdt:P570 ?death.
#             }
#             optional{
#               ?item wdt:P166 ?award.
#             }
#             optional{
#               ?item wdt:P214 ?viaf.
#             }
#             optional{
#               ?item wdt:P244 ?lccn.
#             }
#             optional{
#               ?item wdt:P69 ?education.
#             }
#
#
#
#
#             SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }
#
# {'Q91832319': {'qid': 'Q91832319', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': ['researcher'], 'birth': None, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Sumita Chakraborty', 'award': [], 'education': ['Tata Institute of Fundamental Research']}, 'Q115048549': {'qid': 'Q115048549', 'score': -1, 'score_log': ['No writerly occ'], 'occupation': [], 'birth': None, 'death': None, 'viaf': None, 'lccn': None, 'label': 'Sumita Chakraborty', 'award': ['Kundiman Fellowship'], 'education': ['Emory University', 'Wellesley College']}}
